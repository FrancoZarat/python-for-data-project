# %%
#Primer contacto con las herramientas que voy a utilizar.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[10,20,30,40])
plt.title("Primer grafico")
plt.show()
